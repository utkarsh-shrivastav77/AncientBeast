# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarsh-shrivastav77/AncientBeast/blob/master/Simple_Linear_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.loadtxt("data.csv", delimiter=",")
data.shape
# Out:
# (100, 2)

# %%
 x = data[:,0].reshape(-1,1)
 y = data[:,1].reshape(-1,1)
 x.shape
# Out:
# (100, 1)

# %%
 from sklearn import model_selection
 X_train, X_test, Y_train, Y_test = model_selection.train_test_split(x,y)

# %%
 from sklearn.linear_model import LinearRegression
 alg1 = LinearRegression()
 alg1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print(alg1.coef_)
print(alg1.intercept_)
# Out:
# [[1.35916734]]
# [6.02036902]

# %%
import matplotlib.pyplot as plt
m = alg1.coef_[0]
c = alg1.intercept_[0]

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "c")
train_1d = X_train.reshape(75)
plt.scatter(X_train, Y_train)
plt.show()

# %%
# Testing for the test data
m = alg1.coef_[0]
c = alg1.intercept_[0]

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "c")
train_1d = X_test.reshape(25)
plt.scatter(X_test, Y_test)
plt.show()

# %%
test_score = alg1.score(X_test, Y_test)
training_score = alg1.score(X_train, Y_train)
print(training_score )
# Out:
# 0.6089340155136966
